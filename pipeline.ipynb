# %% [markdown]
# # Pipeline Prototype

# %% [markdown]
# ## Data Wrangling

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Files in the current directory :

# %%
import os
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'pipeline.ipynb', 'README.md', 'sample.tsv', 'schema.txt']

# %% [markdown]
# Import the schema file :

# %%
schema = pd.read_csv('schema.txt', delim_whitespace=True, header=None)
schema
# Out:
#      0               1             2                3           4         5
# 0    1              id    bigint(20)         UNSIGNED          No      None
# 1    2          userId    bigint(20)         UNSIGNED          No      None
# 2    3       createdAt     timestamp               No  0000-00-00  00:00:00
# 3    4            text          text  utf8_unicode_ci          No      None
# 4    5       longitude         float              Yes         NaN       NaN
# 5    6        latitude         float              Yes         NaN       NaN
# 6    7         placeId   varchar(25)  utf8_general_ci         Yes       NaN
# 7    8       inReplyTo    bigint(20)         UNSIGNED         Yes       NaN
# 8    9          source       int(10)         UNSIGNED          No      None
# 9   10       truncated        bit(1)               No        None       NaN
# 10  11   placeLatitude         float              Yes         NaN       NaN
# 11  12  placeLongitude         float              Yes         NaN       NaN
# 12  13      sourceName  varchar(255)  utf8_general_ci         Yes       NaN
# 13  14       sourceUrl  varchar(255)  utf8_general_ci         Yes       NaN
# 14  15        userName  varchar(200)  utf8_general_ci         Yes       NaN
# 15  16      screenName  varchar(200)  utf8_general_ci         Yes       NaN
# 16  17  followersCount       int(10)         UNSIGNED         Yes       NaN
# 17  18    friendsCount       int(10)         UNSIGNED         Yes       NaN
# 18  19   statusesCount       int(10)         UNSIGNED         Yes       NaN
# 19  20    userLocation  varchar(200)  utf8_general_ci         Yes       NaN

# %% [markdown]
# This gives us the position, size and format for each attribute of the data.

# %% [markdown]
# Importing the data sample as provided doesn't work, it seems there are some inconsistency in the data formatting than pandas can't resolve by reading it. So we need to play a little bit with Trifacta in order to get something readable by pandas. We perform the following Trifacta commands on the sample data :
#
# `splitrows col: column1 on: '\n'
# split col: column1 on: '\t' limit: 20
# settype col: column7 type: 'Float'
# settype col: column6 type: 'Float'
# drop col: column11
# `
#
# We see that the last line of the script drops the 11th column of the data. Inspecting this column with Trifacta shows that it's empty. Actually by analysing the raw `.tsv` file, we can see that if the `truncated` feature is 0, then it's not present in the row, so Trifacta can't tell the difference between the truncated and the source feature, which are merged together. We decide then to drop the empty 11th column, mainly because if we import it as it is with pandas, we get some problem with the following columns.
#
# Now we are able to import it with pandas :

# %%
import csv
#df = pd.read_csv('sample.txt', sep='\t', header=None, quoting=csv.QUOTE_NONE)
df = pd.read_csv('sample.csv', na_values='\\N', parse_dates=['column4'])
df
# Out:
#                  column2             column3             column4  \
# 0     776522983837954049  735449229028675584 2016-09-15 20:48:01
# 1     776523000636203010          2741685639 2016-09-15 20:48:05
# 2     776523045200691200           435239151 2016-09-15 20:48:15
# 3     776523058404290560           503244217 2016-09-15 20:48:18
# 4     776523058504925185           452805259 2016-09-15 20:48:18
# 5     776523071025012736            16416746 2016-09-15 20:48:21
# 6     776523092768219137  735449229028675584 2016-09-15 20:48:27
# 7     776523105007177728          2442105406 2016-09-15 20:48:29
# 8     776523126729474048           101489921 2016-09-15 20:48:35
# 9     776523134409244673  715791830294650880 2016-09-15 20:48:37
# 3     @Mno0or_Abyat اشوف مظاهرات على قانون العمل الج...      NaN      NaN
# 4     Greek night #geneve (@ Emilios in Genève) http...  6.14414  46.1966
# 5     @gregorypons #BusinessMontresVision https://t....      NaN      NaN
# 6                         dillo https://t.co/hScjeZbi4c      NaN      NaN
# 7            Miii le voci nere.. Che meraviglia.. #XF10      NaN      NaN
# 8                                @Manu_Aka_Manny Sorry       NaN      NaN
# 9                    Je veut ca https://t.co/NZpSScxQ70      NaN      NaN
# 10                          seh https://t.co/HDbhb8yVma      NaN      NaN
# 11                                        Buenas noches      NaN      NaN
# 12    Am looking like a 2004 kid I swear you looking...      NaN      NaN
# 13    Comunque se sei figa non c'è bisogno di carica...      NaN      NaN
# 14    Abus sexuels: la gym américaine dans la tourme...      NaN      NaN
# 15    @underdeskloser my paypal is insider85@windows...      NaN      NaN
# 16    That's a very interesting score. https://t.co/...      NaN      NaN
# 17                           // https://t.co/Yl5axt9w9x      NaN      NaN
# 18                              https://t.co/Vjvk1YR3LV      NaN      NaN
# 19                         Sexy https://t.co/V7Z48BiSZf      NaN      NaN
# 20    @ABSyst @realDonaldTrump Trump wäre um ein Vie...      NaN      NaN
# 21                            ❤ https://t.co/keGzpzb1xJ      NaN      NaN
# 22                          cos https://t.co/CXlGuOcVkc      NaN      NaN
# 23    Day 15 #WhenWhyHowYouISF some of my rescued gu...      NaN      NaN
# 24                     @LouleGribouille Oh putain ! xDD      NaN      NaN
# 25                                                  NaN      NaN      NaN
# 26                                              #lugano  8.95092  46.0060
# 27    Ma mère ce qu'elle m'a dit elle a grv raison enft      NaN      NaN
# 28    j'aime bien mon prof de droit, mais ses centai...      NaN      NaN
# 29                                Twitter il déconne la      NaN      NaN
# ...                                                 ...      ...      ...
# 8760  @maggets29 ils ont déjà commencé à tourner la ...      NaN      NaN
# 8761     اللهم ارزقني خير ما في هذا اليوم واصرف عني شره      NaN      NaN
# 8762     Ya tout le train qui vient caresser mon chaton      NaN      NaN
# 8763                                Allez-vous en zouuu      NaN      NaN
# 8764                  Visiting #Stockholm this weekend.      NaN      NaN
# 8765                                Bye bye la France !      NaN      NaN
# 8766  "Conosco un paio di rumeni, tipi suge pula che...  8.83488  45.8106
# 8767                                  @_Tospik Grave ^^      NaN      NaN
# 8768  @walliserstefi bi defür allwäg morn morge no c...      NaN      NaN
# 8769  The biggest ever seen!! Love chestnut! @ Artig...  9.87921  45.8590
# 8770  Sous prétexte que t'as une blouse or que eux s...      NaN      NaN
# 8771  // ma che poi Simona&gt;&gt;&gt;&gt;&gt;&gt;&g...      NaN      NaN
# 8772                                          Up Up Up       NaN      NaN
# 8773  Laurent Haug @ Techno-Pôle de Sierre (TechnoAr...  7.53810  46.2830
# 8774  @elnrbzn non le design lol après la qualité là...      NaN      NaN
# 8775  Rencontre du troisième type avec un dieu du sl...      NaN      NaN
# 8776  « Si l'#entrepreneur est lucide, il parle de s...      NaN      NaN
# 8777                     @Serial_Mother67 Pas de souci       NaN      NaN
# 8778  @ambelman @MaulidarZk @SkySportMotoGP @solomot...      NaN      NaN
# 8779  @MarkGSparrow I'll admit that it was difficult...      NaN      NaN
# 8766  04578354cff6f4b1           NaN         7   45.8314   8.80651
# 8767  12eb9b254faf37a3  7.768205e+17     18777   47.2010   5.94082
# 8768  3762f0997bd0c84b  7.768208e+17         5   47.4987   8.73303
# 8769  77e82c21f6d02bec           NaN         7   45.8615   9.88592
# 8770  3f056fa44e682001           NaN         1   47.7170   7.34480
# 8771  51c0e6b24c64e54e           NaN         1   46.0027   8.96044
# 8772  d8a4789a6a19c18a  7.767972e+17         1   47.5455   7.53449
# 8773  c93881a286a4c206           NaN         7   46.2763   7.50487
# 8774  1ec449abab9e0ec8  7.768211e+17         1   47.7218   7.28274
# 8775  c93881a286a4c206           NaN         1   46.2763   7.50487
# 8776  a3a7268e06eea30f           NaN         5   46.3707   6.16723
# 8777  1ebde7593f067b2c  7.768210e+17         1   46.1763   6.21703
# 8778  c4563855415cca83  7.768127e+17         5   46.7040   7.05738
# 8779  2c6882293dd8c78f  7.768206e+17     18777   47.1354   8.52637
# 8780  4cb84b806fae5001           NaN         1   47.7157   7.35819
# 8781  8b3e53628223753a           NaN     19313   47.0408   8.31721
# 8782  8b3e53628223753a  7.768210e+17     18777   47.0408   8.31721
# 8783  81991650ba79e853           NaN         1   47.4412   8.68313
# 8784  4e7c21fd2af027c6           NaN         1   46.8131   8.22414
# 8785  e21f20072e8bc5e3  7.768138e+17         5   46.8510   8.67273
# 8786  8b3e53628223753a           NaN     19313   47.0408   8.31721
# 8787  437d6bc9209a86f7           NaN         1   46.0404   6.54653
# 8788  04578354cff6f4b1           NaN         5   45.8314   8.80651
# 8789  3ea75b7392b74cae           NaN     18777   47.1425   6.19758
#
#                  column14                               column15  \
# 0      Twitter for iPhone  http://twitter.com/#!/download/iphone
# 1      Twitter for iPhone  http://twitter.com/#!/download/iphone
# 2     Twitter for Android    http://twitter.com/download/android
# 3      Twitter for iPhone  http://twitter.com/#!/download/iphone
# 4              foursquare                  http://foursquare.com
# 5      Twitter Web Client                     http://twitter.com
# 6      Twitter for iPhone  http://twitter.com/#!/download/iphone
# 7     Twitter for Android    http://twitter.com/download/android
# 8      Twitter for iPhone  http://twitter.com/#!/download/iphone
# 9     Twitter for Android    http://twitter.com/download/android
# 10     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 11    Twitter for Android    http://twitter.com/download/android
# 12     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 13     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 14     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 15     Twitter Web Client                     http://twitter.com
# 16     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 17     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 18     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 19    Twitter for Android    http://twitter.com/download/android
# 20     Twitter Web Client                     http://twitter.com
# 21    Twitter for Android    http://twitter.com/download/android
# 22     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 23     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 24     Twitter Web Client                     http://twitter.com
# 25     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 26              Instagram                      http://instagr.am
# 27     Twitter for iPhone  http://twitter.com/#!/download/iphone
# 28     Twitter Web Client                     http://twitter.com
# 29     Twitter for iPhone  http://twitter.com/#!/download/iphone
# ...                   ...                                    ...
# 8760  Twitter for Android    http://twitter.com/download/android
# 8761   Twitter Web Client                     http://twitter.com
# 8762   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8763   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8764  Twitter for Android    http://twitter.com/download/android
# 8765   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8766            Instagram                      http://instagr.am
# 8767   Twitter Web Client                     http://twitter.com
# 8768  Twitter for Android    http://twitter.com/download/android
# 8769            Instagram                      http://instagr.am
# 8770   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8771   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8772   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8773            Instagram                      http://instagr.am
# 8774   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8775   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8776  Twitter for Android    http://twitter.com/download/android
# 8777   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8778  Twitter for Android    http://twitter.com/download/android
# 8779   Twitter Web Client                     http://twitter.com
# 8780   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8781          Poke Luzern         https://twitter.com/pokeluzern
# 8782   Twitter Web Client                     http://twitter.com
# 8783   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8784   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8785  Twitter for Android    http://twitter.com/download/android
# 8786          Poke Luzern         https://twitter.com/pokeluzern
# 8787   Twitter for iPhone  http://twitter.com/#!/download/iphone
# 8788  Twitter for Android    http://twitter.com/download/android
# 8789   Twitter Web Client                     http://twitter.com
#
#                   column16         column17  column18  column19  column20  \
# 0          plvtone filiae.        hazel_chb       146       110     28621
# 1                   samara         letisieg       755      2037      3771
# 2                lebrübrü❤         lebrubru       811       595     30191
# 3           عبدالله القنيص         bingnais     28433       417     12262
# 4              Alkan Şenli         Alkanoli       204       172      3390
# 5             Gregory PONS      gregorypons      2398       305     14917
# 6          plvtone filiae.        hazel_chb       146       110     28621
# 7           Roberta Perani      robertabg72       971      1753      8181
# 8       Martina Ferraiuolo  martiferraiuolo       530       308      9610
# 9                 analslut     doggyboynude      1206      2503       815
# 10         plvtone filiae.        hazel_chb       146       110     28621
# 11            somos amigos        FanGreece       155       183        55
# 12                 Mercyda      Mercydasexy        50        92       139
# 13        Lorenzo Buccheri  LorenzoBuccheri       209        61      7069
# 14           Arménio Costa        menicosta       268      1325      2542
# 15                   david        dassange5       409       841      1424
# 16            David Childs      DavidChilds      1243      1085     16287
# 17         plvtone filiae.        hazel_chb       146       110     28621
# 18                  samara         letisieg       755      2037      3771
# 19                analslut     doggyboynude      1206      2503       815
# 20           swissbusiness    swissbusiness     96181     93556    207521
# 21                Kesia. ∞   25novembre2014       446       296     21308
# 22         plvtone filiae.        hazel_chb       146       110     28621
# 23        Keep Smiling :-)    oh_my_Kristen     10099      8549     37319
# 24              ☆NinjAlei☆         Aleimine       302       452      7753
# 25                  Vanè ♡   vanessagarciar        56        37       733
# 26             Lone Ranger        forager01        27       124      3761
# 27                Diabinha  Messiiiiiiiiiie      1169       635     81787
# 28            Œil Critique       OeilKritik        57        84      7780
# 29                 bushraa    viededingue__       157        27      7282
# ...                    ...              ...       ...       ...       ...
# 8760                Elodie         Elogleek       389       917     26663
# 8761     yasar koul Aghasi     Yasar_aghasi      4468      3806      8250
# 8762                 angie       desmonnard       472       481     19951
# 8763                 angie       desmonnard       472       481     19951
# 8764        Sebastian Gräf      sebastian_g       557       287       647
# 8765              Juliette     JulietteGlln       528        84     37070
# 8766                  Edg3      therealedg3       380       196     15724
# 8767              Aymeric           Biboux_      4531       209     24864
# 8768      Marc Aeschlimann      the_aeschli       240       435      6246
# 8769    LaDameBiereBlanche      Biricoccoli        40       128       172
# 8770             FerinaVie        KellyDaSi       401       215     20930
# 8771       plvtone filiae.        hazel_chb       146       110     28621
# 8772          SwissRolling      swissroling      3351        29      2509
# 8773          Loic Le Meur             loic    128526       862     54222
# 8774                 fa2ny           fxarb_       335       106     32122
# 8775         Thierry Weber     thierryweber      7427      2934     21335
# 8776            Yan Burrin          YBurrin       434       450       964
# 8777          $P€NC€R R€ID        jazz74100      1193      1339    150152
# 8778        Wrecked Clutch       traxtorm78       115       319      1101
# 8779     Brummie Auslander  exiledenglander      1066       800     34071
# 8780             FerinaVie        KellyDaSi       401       215     20930
# 8781           Poke Luzern       pokeluzern         5         0      5319
# 8782             Lari Reis     bloglarireis       250        37      3731
# 8783             Stefan H.    walliserstefi       262       437      2686
# 8784             Sipra Roy         SipraRoy       300       623       400
# 8785      Lukas Martinelli    lukmartinelli      1128       679       741
# 8786           Poke Luzern       pokeluzern         5         0      5319
# 8787                Séb217           Seb217       223       887     10416
# 8788          umberto rega      umbertorega       442       431      9414
# 8789  France3Franche-Comté   F3FrancheComte      9845       381     17440
#
#                          column21  column22
# 0                       Earleen.        NaN
# 1                          Suisse       NaN
# 2                         Fontain       NaN
# 3                       Shargeyah       NaN
# 4              İstanbul/Burgazada       NaN
# 5     Geneva + watchmaking planet       NaN
# 6                       Earleen.        NaN
# 7                             NaN       NaN
# 8                   Varese, Italy       NaN
# 9                          france       NaN
# 10                      Earleen.        NaN
# 11                  Bern, Schweiz       NaN
# 12                        Austria       NaN
# 13              Varese, Lombardia       NaN
# 14                Genève - Suisse       NaN
# 15                            NaN       NaN
# 16            Zurich, Switzerland       NaN
# 17                      Earleen.        NaN
# 18                         Suisse       NaN
# 19                         france       NaN
# 20                         Zurich       NaN
# 21                          Como        NaN
# 22                      Earleen.        NaN
# 23               isfoundation.com       NaN
# 24                            NaN       NaN
# 25                            NaN       NaN
# 26                        Lahore        NaN
# 27                 Genève, Suisse       NaN
# 28                 Genève, Suisse       NaN
# 29            Montbéliard, France       NaN
# ...                           ...       ...
# 8760         Besançon (25) FRANCE       NaN
# 8761                  Switzerland       NaN
# 8762                       geneva       NaN
# 8763                       geneva       NaN
# 8764          Zurich, Switzerland       NaN
# 8765            28fevrier2012 P❤️       NaN
# 8766                       Varese       NaN
# 8767  → Besançon - Franche Comté        NaN
# 8768                   Winterthur       NaN
# 8769                        Italy       NaN
# 8770                 ouloulouland       NaN
# 8771                    Earleen.        NaN
# 8772        Allschwil, Basel-Land       NaN
# 8773                San Francisco       NaN
# 8774                     g-eazy❤️       NaN
# 8775              breew, lausanne       NaN
# 8776                    Borex, VD       NaN
# 8777       Annemasse, Rhône-Alpes       NaN
# 8778  Vuisternens-en-Ogoz  Suisse       NaN
# 8779                  Switzerland       NaN
# 8780                 ouloulouland       NaN
# 8781                          NaN       NaN
# 8782                           SP       NaN
# 8783                   Oberwallis       NaN
# 8784                San Francisco       NaN
# 8785          Zurich, Switzerland       NaN
# 8786                          NaN       NaN
# 8787                       RA, FR       NaN
# 8788              Varese - Italia       NaN
# 8789                     Besançon       NaN
#
# [8790 rows x 20 columns]
